# %% [markdown]
# # Carbon - Kaggle Environment

# %%
import sys
sys.path.append("../../../")

from zerosum_env import make
env = make("carbon")
print(env.name, env.version)
print("Default Agents: ", *env.agents)
# Out:
# Carbon Neutrality 1.0.0
# Default Agents:  random my_agent other_agent

# %% [markdown]
# ## TLDR;

# %%
from zerosum_env import make
from random import choice
from zerosum_env.envs.carbon.helpers import *

def my_agent(observation, configuration):

  board = Board(observation, configuration)
  me = board.current_player

  # 给自身所有捕碳员下达往上移动的指令
  for worker in me.collectors:
    worker.next_action = WorkerAction.UP
  
  # 给自身所有种树员下达往下移动的指令
  for worker in me.plantors:
    worker.next_action = WorkerAction.DOWN
  
  # 给自身所有捕碳员下达往左移动的指令
  for worker in me.collectors:
    worker.next_action = WorkerAction.LEFT
  
  # 给自身所有种树员下达往右移动的指令
  for worker in me.plantors:
    worker.next_action = WorkerAction.RIGHT

  # 给自身所有转化中心下达招募捕碳员的指令
  for recrtCenter in me.recrtCenters:
    recrtCenter.next_action = RecrtCenterAction.RECCOLLECTOR

  # 给自身所有转化中心下达招募种树员的指令
  for recrtCenter in me.recrtCenters:
    recrtCenter.next_action = RecrtCenterAction.RECPLANTOR
      
  # 给环境返回指令
  return me.next_actions

def agent(obs):
    action = {}
    worker_id = list(obs.players[obs.player][1].keys())[0]
    if obs.players[obs.player][2] != {}:
        worker_id = list(obs.players[obs.player][2].keys())[0]
#     'RECCOLLECTOR',
    worker_action = choice([ 'RECPLANTOR', 'UP', 'DOWN', 'RIGHT', 'LEFT', None])
    if worker_action is not None:
        action[worker_id] = worker_action
#     print(action)
    return action

env = make("carbon", debug=True)
env.run([agent, my_agent])
env.render(mode="ipython", width=1000, height=800)
# print(env.render(mode="json"))
# Out:
# <iframe srcdoc="<!--
#   Copyright 2020 Kaggle Inc
#
#   Licensed under the Apache License, Version 2.0 (the &quot;License&quot;);
#   you may not use this file except in compliance with the License.
#   You may obtain a copy of the License at
#
#       http://www.apache.org/licenses/LICENSE-2.0
#
#   Unless required by applicable law or agreed to in writing, software
#   distributed under the License is distributed on an &quot;AS IS&quot; BASIS,
#   WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
#   See the License for the specific language governing permissions and
#   limitations under the License.
# -->
# <!DOCTYPE html>
# <html lang=&quot;zh-cn&quot;>
#   <head>
#     <title>Kaggle Simulation Player</title>
#     <meta name=&quot;viewport&quot; content=&quot;width=device-width,initial-scale=1&quot; charset=&quot;utf-8&quot;/>
#     <link
#       rel=&quot;stylesheet&quot;
# ...

# %% [markdown]
# ## Specification

# %%
import json
print("Configuration:", json.dumps(env.specification.configuration, indent=4, sort_keys=True))
print("Observation:", json.dumps(env.specification.observation, indent=4, sort_keys=True))
print("Action:", json.dumps(env.specification.action, indent=4, sort_keys=True))
# Out:
# Configuration: {
#     "actTimeout": {
#         "default": 1,
#         "description": "Maximum runtime (seconds) to obtain an action from an agent.",
#         "minimum": 0,
#         "type": "number"
#     },
#     "agentTimeout": {
#         "default": 60,
#         "description": "Obsolete field kept for backwards compatibility, please use observation.remainingOverageTime.",
#         "minimum": 0,
#         "type": "number"
#     },
#     "co2FrmWithered": {
#         "default": 5,
#         "description": "The amount of carbon from withered tree.",
#         "minimum": 0,
#         "type": "integer"
#     },
#     "collectRate": {
#         "default": 0.25,
#         "description": "The rate of collector collected from a cell by not moving.",
#         "minimum": 0,
#         "type": "number"
#     },
#     "collectorLimit": {
#         "default": 2,
#         "description": "The limitation of collector.",
#         "minimum": 0,
#         "type": "integer"
#     },
# ...
